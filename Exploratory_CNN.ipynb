# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torchvision.ops as ops
import random
import numpy as np

print(torch.__version__)
# Out:
# 2.1.0+cu121

# %%
print(f"Is CUDA supported by this system?{torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
# Out:
# Is CUDA supported by this system?True
# CUDA version: 12.1

# %%
def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    np.random.seed(seed)
    random.seed(seed)

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

# %%
train_dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
class MyModel(nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()
        
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=5, padding=2), #1x28x28 -> 32x28x28
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2) #32x14x14
        )
        
        self.layer2 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, padding=2), #32x14x14 -> 64x14x14
            nn.ReLU(),
            nn.MaxPool2d(2, 2) #64x7x7
        )
        
        self.fcl = nn.Sequential(
            nn.Linear(in_features=64 * 7 * 7, out_features=1024),
            nn.Dropout(0.2),
            nn.Linear(in_features=1024, out_features=10)
        )
        
    def forward(self, x):
        x = self.layer1(x)
        x = self.layer2(x)
        x = x.view(x.size(0), -1)
        out = self.fcl(x)
        return out

# %%
# Choose a loss function for training
loss_fn = nn.CrossEntropyLoss()
setup_seed(0)
device = torch.device("cuda")
model = MyModel().to(device)

def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    train_loss, correct = 0, 0
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)
        
        train_loss += loss.item()
        correct += (pred.argmax(1) == y).type(torch.float).sum().item()

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    train_loss /= num_batches
    correct /= size
    print(f"Train Error: \n Accuracy: {(correct*100):>0.1f}%, Avg loss: {train_loss:>8f}")
    
    return train_loss, correct

def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    
    return test_loss, correct

# %%
# Main function: train and test the model
def main(chosen=""):
    EPOCHS = 30
    if not bool(chosen):
        optimisers = ['SGD', 'Momentum', 'Adagrad', 'RMSprop', 'Adam']
    else:
        optimisers = [chosen]

    for myoptimizer in optimisers:
        # Create an instance of the model
        model = MyModel()
        print('Training with: '+myoptimizer+'...')
        if myoptimizer == 'SGD':
            optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)
        elif myoptimizer == 'Momentum':
            optimizer = torch.optim.SGD(model.parameters(), lr=1e-3, momentum=0.9)
        elif myoptimizer == 'Adagrad':
            optimizer = torch.optim.Adagrad(model.parameters(), lr=1e-3)
        elif myoptimizer == 'RMSprop':
            optimizer = torch.optim.RMSprop(model.parameters(), lr=1e-3)
        elif myoptimizer == 'Adam':
            optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
        else:
            print("Wrong optimizer type")
            continue

    train_loss, test_loss = [], []
    train_acc, test_acc = [], []
    for t in range(EPOCHS):
        print(f"Epoch {t+1}\n-------------------------------")
        loss, acc = train_loop(train_dataloader, model, loss_fn, optimizer)
        train_loss.append(loss), train_acc.append(acc)

        loss, acc = test_loop(test_dataloader, model, loss_fn)
        test_loss.append(loss), test_acc.append(acc)
    print("Done!")
    
    return test_acc[-1], test_loss[-1]

# %%
layer = 2
acc_dict, fcl_dict, channels_dict, deform_dict = {},{},{},{}
test_acc, test_loss = main("Adam")
acc_dict[layer] = [(test_acc*100), test_loss]
# Out:
# Training with: Adam...
# Epoch 1
# -------------------------------
# Train Error:
#  Accuracy: 85.3%, Avg loss: 0.408266
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.313593
#
# Epoch 2
# -------------------------------
# Train Error:
#  Accuracy: 90.0%, Avg loss: 0.278080
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.287211
#
# Epoch 3
# -------------------------------
# Train Error:
#  Accuracy: 91.2%, Avg loss: 0.243877
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.284087
#
# Epoch 4
# -------------------------------
# Train Error:
#  Accuracy: 92.1%, Avg loss: 0.219319
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.310676
#
# Epoch 5
# -------------------------------
# Train Error:
#  Accuracy: 92.8%, Avg loss: 0.198164
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.285537
#
# Epoch 6
# -------------------------------
# Train Error:
#  Accuracy: 93.4%, Avg loss: 0.182924
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.274848
#
# Epoch 7
# -------------------------------
# Train Error:
#  Accuracy: 93.8%, Avg loss: 0.168447
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.285078
#
# Epoch 8
# -------------------------------
# Train Error:
#  Accuracy: 94.3%, Avg loss: 0.154628
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.317865
#
# Epoch 9
# -------------------------------
# Train Error:
#  Accuracy: 94.8%, Avg loss: 0.142353
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.310546
#
# Epoch 10
# -------------------------------
# Train Error:
#  Accuracy: 95.2%, Avg loss: 0.130401
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.366992
#
# Epoch 11
# -------------------------------
# Train Error:
#  Accuracy: 95.5%, Avg loss: 0.124593
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.350764
#
# Epoch 12
# -------------------------------
# Train Error:
#  Accuracy: 95.8%, Avg loss: 0.112940
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.396027
#
# Epoch 13
# -------------------------------
# Train Error:
#  Accuracy: 96.1%, Avg loss: 0.107270
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.398593
#
# Epoch 14
# -------------------------------
# Train Error:
#  Accuracy: 96.3%, Avg loss: 0.100820
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.392800
#
# Epoch 15
# -------------------------------
# Train Error:
#  Accuracy: 96.7%, Avg loss: 0.091079
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.423931
#
# Epoch 16
# -------------------------------
# Train Error:
#  Accuracy: 96.6%, Avg loss: 0.093723
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.438562
#
# Epoch 17
# -------------------------------
# Train Error:
#  Accuracy: 96.8%, Avg loss: 0.087141
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.423596
#
# Epoch 18
# -------------------------------
# Train Error:
#  Accuracy: 97.0%, Avg loss: 0.085240
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.448217
#
# Epoch 19
# -------------------------------
# Train Error:
#  Accuracy: 97.3%, Avg loss: 0.073464
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.501450
#
# Epoch 20
# -------------------------------
# Train Error:
#  Accuracy: 97.1%, Avg loss: 0.078777
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.526718
#
# Epoch 21
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.069235
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.537858
#
# Epoch 22
# -------------------------------
# Train Error:
#  Accuracy: 97.6%, Avg loss: 0.067274
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.552529
#
# Epoch 23
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.071355
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.542179
#
# Epoch 24
# -------------------------------
# Train Error:
#  Accuracy: 97.7%, Avg loss: 0.067799
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.566473
#
# Epoch 25
# -------------------------------
# Train Error:
#  Accuracy: 97.9%, Avg loss: 0.059934
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.572867
#
# Epoch 26
# -------------------------------
# Train Error:
#  Accuracy: 97.8%, Avg loss: 0.062054
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.641838
#
# Epoch 27
# -------------------------------
# Train Error:
#  Accuracy: 97.9%, Avg loss: 0.059708
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.675026
#
# Epoch 28
# -------------------------------
# Train Error:
#  Accuracy: 97.8%, Avg loss: 0.066266
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.614496
#
# Epoch 29
# -------------------------------
# Train Error:
#  Accuracy: 97.9%, Avg loss: 0.064147
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.656281
#
# Epoch 30
# -------------------------------
# Train Error:
#  Accuracy: 98.1%, Avg loss: 0.056451
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.689384
#
# Done!

# %%
acc_dict
# Out:
# {2: [89.32, 0.6893838126758102]}

# %%
class MyDynamicModel(nn.Module):
    def __init__(self, num_layers=2, num_fcl_layers=1, input_size=28):
        super(MyDynamicModel, self).__init__()
        self.num_layers = num_layers
        
        self.layers = nn.ModuleList()
        
        self.layers.append(nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=5, padding=2), #1x28x28 -> 32x28x28
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2) #32x14x14
        ))
        input_size//=2
        for i in range(1, self.num_layers):
            self.layers.append(nn.Sequential(
            nn.Conv2d(in_channels=32*i, out_channels=32*(i+1), kernel_size=5, padding=2), #32x14x14 -> 64x14x14
            nn.ReLU(),
            nn.MaxPool2d(2, 2) #64x7x7
            ))
            input_size//=2
        
        self.fc_layers = nn.ModuleList()
        self.num_fcl_layers = num_fcl_layers
        
        output = 1024
        self.fc_layers.append(nn.Sequential(
                nn.Linear(in_features=64 * input_size * input_size, out_features=1024),
                nn.Dropout(0.2)
            ))
        
        prev_output = output
        output//=2
        for i in range(self.num_fcl_layers):
            self.fc_layers.append(nn.Sequential(
                nn.Linear(in_features=prev_output, out_features=output),
                nn.Dropout(0.2)
            ))
            prev_output = output
            output//=2
            
        nn.Linear(in_features=1024, out_features=10)
        
    def forward(self, x):
        for layer in self.layers:
            x = layer(x)

        x = x.view(x.size(0), -1)
        
        for layer in self.fc_layers:
            x = layer(x)
        
        out = self.additional_fc(x)
        return out

# %%
for layer in range(3,5):
    print(f"No. of layers: {layer}")
    model = MyDynamicModel(num_layers=layer)
    test_acc, test_loss = main("Adam")
    acc_dict[layer] = [(test_acc*100), test_loss]
    print(acc_dict)
# Out:
# No. of layers: 3
# Training with: Adam...
# Epoch 1
# -------------------------------
# Train Error:
#  Accuracy: 85.1%, Avg loss: 0.417351
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.324096
#
# Epoch 2
# -------------------------------
# Train Error:
#  Accuracy: 89.9%, Avg loss: 0.281271
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.303325
#
# Epoch 3
# -------------------------------
# Train Error:
#  Accuracy: 91.1%, Avg loss: 0.245987
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.279941
#
# Epoch 4
# -------------------------------
# Train Error:
#  Accuracy: 92.0%, Avg loss: 0.220761
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.279595
#
# Epoch 5
# -------------------------------
# Train Error:
#  Accuracy: 92.6%, Avg loss: 0.204487
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.291337
#
# Epoch 6
# -------------------------------
# Train Error:
#  Accuracy: 93.2%, Avg loss: 0.186450
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.283019
#
# Epoch 7
# -------------------------------
# Train Error:
#  Accuracy: 93.7%, Avg loss: 0.173789
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.299866
#
# Epoch 8
# -------------------------------
# Train Error:
#  Accuracy: 94.2%, Avg loss: 0.161055
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.298543
#
# Epoch 9
# -------------------------------
# Train Error:
#  Accuracy: 94.5%, Avg loss: 0.149981
# Test Error:
#  Accuracy: 91.3%, Avg loss: 0.304144
#
# Epoch 10
# -------------------------------
# Train Error:
#  Accuracy: 94.9%, Avg loss: 0.140686
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.313612
#
# Epoch 11
# -------------------------------
# Train Error:
#  Accuracy: 95.1%, Avg loss: 0.131994
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.328581
#
# Epoch 12
# -------------------------------
# Train Error:
#  Accuracy: 95.5%, Avg loss: 0.124074
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.342477
#
# Epoch 13
# -------------------------------
# Train Error:
#  Accuracy: 95.8%, Avg loss: 0.115689
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.348835
#
# Epoch 14
# -------------------------------
# Train Error:
#  Accuracy: 96.1%, Avg loss: 0.108051
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.358464
#
# Epoch 15
# -------------------------------
# Train Error:
#  Accuracy: 96.4%, Avg loss: 0.099604
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.373807
#
# Epoch 16
# -------------------------------
# Train Error:
#  Accuracy: 96.5%, Avg loss: 0.096112
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.393811
#
# Epoch 17
# -------------------------------
# Train Error:
#  Accuracy: 96.5%, Avg loss: 0.096448
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.405511
#
# Epoch 18
# -------------------------------
# Train Error:
#  Accuracy: 96.9%, Avg loss: 0.084508
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.433273
#
# Epoch 19
# -------------------------------
# Train Error:
#  Accuracy: 96.9%, Avg loss: 0.086244
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.437640
#
# Epoch 20
# -------------------------------
# Train Error:
#  Accuracy: 97.0%, Avg loss: 0.082858
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.464879
#
# Epoch 21
# -------------------------------
# Train Error:
#  Accuracy: 97.3%, Avg loss: 0.075875
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.456641
#
# Epoch 22
# -------------------------------
# Train Error:
#  Accuracy: 97.4%, Avg loss: 0.072825
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.507471
#
# Epoch 23
# -------------------------------
# Train Error:
#  Accuracy: 97.3%, Avg loss: 0.075467
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.517088
#
# Epoch 24
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.071564
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.511677
#
# Epoch 25
# -------------------------------
# Train Error:
#  Accuracy: 97.6%, Avg loss: 0.067617
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.556566
#
# Epoch 26
# -------------------------------
# Train Error:
#  Accuracy: 97.7%, Avg loss: 0.067879
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.569981
#
# Epoch 27
# -------------------------------
# Train Error:
#  Accuracy: 97.7%, Avg loss: 0.066699
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.607893
#
# Epoch 28
# -------------------------------
# Train Error:
#  Accuracy: 97.8%, Avg loss: 0.065765
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.587572
#
# Epoch 29
# -------------------------------
# Train Error:
#  Accuracy: 97.7%, Avg loss: 0.064568
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.605516
#
# Epoch 30
# -------------------------------
# Train Error:
#  Accuracy: 98.0%, Avg loss: 0.059484
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.636592
#
# Done!
# {2: [89.32, 0.6893838126758102], 3: [89.32, 0.6365924760889096]}
# No. of layers: 4
# Training with: Adam...
# Epoch 1
# -------------------------------
# Train Error:
#  Accuracy: 84.8%, Avg loss: 0.425201
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.325617
#
# Epoch 2
# -------------------------------
# Train Error:
#  Accuracy: 89.6%, Avg loss: 0.285122
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.280979
#
# Epoch 3
# -------------------------------
# Train Error:
#  Accuracy: 91.1%, Avg loss: 0.247332
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.276295
#
# Epoch 4
# -------------------------------
# Train Error:
#  Accuracy: 91.6%, Avg loss: 0.228276
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.286440
#
# Epoch 5
# -------------------------------
# Train Error:
#  Accuracy: 92.3%, Avg loss: 0.210061
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.286185
#
# Epoch 6
# -------------------------------
# Train Error:
#  Accuracy: 92.8%, Avg loss: 0.193820
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.289941
#
# Epoch 7
# -------------------------------
# Train Error:
#  Accuracy: 93.4%, Avg loss: 0.180858
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.300087
#
# Epoch 8
# -------------------------------
# Train Error:
#  Accuracy: 93.9%, Avg loss: 0.167553
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.298745
#
# Epoch 9
# -------------------------------
# Train Error:
#  Accuracy: 94.2%, Avg loss: 0.158912
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.310712
#
# Epoch 10
# -------------------------------
# Train Error:
#  Accuracy: 94.4%, Avg loss: 0.150861
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.312742
#
# Epoch 11
# -------------------------------
# Train Error:
#  Accuracy: 94.9%, Avg loss: 0.140332
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.348854
#
# Epoch 12
# -------------------------------
# Train Error:
#  Accuracy: 95.2%, Avg loss: 0.132878
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.334316
#
# Epoch 13
# -------------------------------
# Train Error:
#  Accuracy: 95.4%, Avg loss: 0.125738
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.355358
#
# Epoch 14
# -------------------------------
# Train Error:
#  Accuracy: 95.6%, Avg loss: 0.118576
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.362405
#
# Epoch 15
# -------------------------------
# Train Error:
#  Accuracy: 95.9%, Avg loss: 0.113410
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.382018
#
# Epoch 16
# -------------------------------
# Train Error:
#  Accuracy: 96.1%, Avg loss: 0.106824
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.395879
#
# Epoch 17
# -------------------------------
# Train Error:
#  Accuracy: 96.3%, Avg loss: 0.102306
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.417882
#
# Epoch 18
# -------------------------------
# Train Error:
#  Accuracy: 96.5%, Avg loss: 0.095735
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.399331
#
# Epoch 19
# -------------------------------
# Train Error:
#  Accuracy: 96.6%, Avg loss: 0.094619
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.435173
#
# Epoch 20
# -------------------------------
# Train Error:
#  Accuracy: 96.6%, Avg loss: 0.093064
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.448929
#
# Epoch 21
# -------------------------------
# Train Error:
#  Accuracy: 96.8%, Avg loss: 0.088301
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.497566
#
# Epoch 22
# -------------------------------
# Train Error:
#  Accuracy: 97.0%, Avg loss: 0.085577
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.459762
#
# Epoch 23
# -------------------------------
# Train Error:
#  Accuracy: 97.1%, Avg loss: 0.080456
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.522569
#
# Epoch 24
# -------------------------------
# Train Error:
#  Accuracy: 97.1%, Avg loss: 0.081860
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.513700
#
# Epoch 25
# -------------------------------
# Train Error:
#  Accuracy: 97.3%, Avg loss: 0.075390
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.573939
#
# Epoch 26
# -------------------------------
# Train Error:
#  Accuracy: 97.2%, Avg loss: 0.075328
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.560230
#
# Epoch 27
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.071406
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.589405
#
# Epoch 28
# -------------------------------
# Train Error:
#  Accuracy: 97.3%, Avg loss: 0.075885
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.591061
#
# Epoch 29
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.069378
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.613006
#
# Epoch 30
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.071515
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.610665
#
# Done!
# {2: [89.32, 0.6893838126758102], 3: [89.32, 0.6365924760889096], 4: [89.49000000000001, 0.6106650411703025]}

# %%
for fcl_layer in range(2,7):
    print(f"No. of fcl: {fcl_layer}")
    model = MyDynamicModel(num_fcl_layers=fcl_layer)
    test_acc, test_loss = main("Adam")
    fcl_dict[fcl_layer] = [(test_acc*100), test_loss]
    print(fcl_dict)
# Out:
# No. of fcl: 2
# Training with: Adam...
# Epoch 1
# -------------------------------
# Train Error:
#  Accuracy: 85.4%, Avg loss: 0.408927
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.341121
#
# Epoch 2
# -------------------------------
# Train Error:
#  Accuracy: 89.7%, Avg loss: 0.281095
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.291660
#
# Epoch 3
# -------------------------------
# Train Error:
#  Accuracy: 91.1%, Avg loss: 0.245244
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.285025
#
# Epoch 4
# -------------------------------
# Train Error:
#  Accuracy: 92.0%, Avg loss: 0.220650
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.279671
#
# Epoch 5
# -------------------------------
# Train Error:
#  Accuracy: 92.7%, Avg loss: 0.200565
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.266852
#
# Epoch 6
# -------------------------------
# Train Error:
#  Accuracy: 93.0%, Avg loss: 0.187930
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.293506
#
# Epoch 7
# -------------------------------
# Train Error:
#  Accuracy: 93.6%, Avg loss: 0.172682
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.309526
#
# Epoch 8
# -------------------------------
# Train Error:
#  Accuracy: 94.2%, Avg loss: 0.160033
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.306199
#
# Epoch 9
# -------------------------------
# Train Error:
#  Accuracy: 94.6%, Avg loss: 0.150399
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.304812
#
# Epoch 10
# -------------------------------
# Train Error:
#  Accuracy: 94.9%, Avg loss: 0.139748
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.338315
#
# Epoch 11
# -------------------------------
# Train Error:
#  Accuracy: 95.2%, Avg loss: 0.133877
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.357575
#
# Epoch 12
# -------------------------------
# Train Error:
#  Accuracy: 95.5%, Avg loss: 0.121390
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.351913
#
# Epoch 13
# -------------------------------
# Train Error:
#  Accuracy: 95.9%, Avg loss: 0.113032
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.379019
#
# Epoch 14
# -------------------------------
# Train Error:
#  Accuracy: 96.1%, Avg loss: 0.107361
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.426179
#
# Epoch 15
# -------------------------------
# Train Error:
#  Accuracy: 96.1%, Avg loss: 0.107435
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.427912
#
# Epoch 16
# -------------------------------
# Train Error:
#  Accuracy: 96.5%, Avg loss: 0.099714
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.426774
#
# Epoch 17
# -------------------------------
# Train Error:
#  Accuracy: 96.5%, Avg loss: 0.095172
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.433161
#
# Epoch 18
# -------------------------------
# Train Error:
#  Accuracy: 96.8%, Avg loss: 0.088256
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.446548
#
# Epoch 19
# -------------------------------
# Train Error:
#  Accuracy: 96.9%, Avg loss: 0.084503
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.496499
#
# Epoch 20
# -------------------------------
# Train Error:
#  Accuracy: 96.9%, Avg loss: 0.085538
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.502816
#
# Epoch 21
# -------------------------------
# Train Error:
#  Accuracy: 97.1%, Avg loss: 0.079721
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.500080
#
# Epoch 22
# -------------------------------
# Train Error:
#  Accuracy: 97.3%, Avg loss: 0.076996
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.551244
#
# Epoch 23
# -------------------------------
# Train Error:
#  Accuracy: 97.4%, Avg loss: 0.074482
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.564842
#
# Epoch 24
# -------------------------------
# Train Error:
#  Accuracy: 97.2%, Avg loss: 0.078209
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.519013
#
# Epoch 25
# -------------------------------
# Train Error:
#  Accuracy: 97.7%, Avg loss: 0.063592
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.572675
#
# Epoch 26
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.072239
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.636316
#
# Epoch 27
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.070320
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.624546
#
# Epoch 28
# -------------------------------
# Train Error:
#  Accuracy: 97.7%, Avg loss: 0.065724
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.652829
#
# Epoch 29
# -------------------------------
# Train Error:
#  Accuracy: 97.8%, Avg loss: 0.064589
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.647572
#
# Epoch 30
# -------------------------------
# Train Error:
#  Accuracy: 97.8%, Avg loss: 0.063465
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.699440
#
# Done!
# {2: [89.27000000000001, 0.6994404390833939]}
# No. of fcl: 3
# Training with: Adam...
# Epoch 1
# -------------------------------
# Train Error:
#  Accuracy: 85.2%, Avg loss: 0.413287
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.320417
#
# Epoch 2
# -------------------------------
# Train Error:
#  Accuracy: 89.8%, Avg loss: 0.280404
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.353545
#
# Epoch 3
# -------------------------------
# Train Error:
#  Accuracy: 91.3%, Avg loss: 0.245103
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.284210
#
# Epoch 4
# -------------------------------
# Train Error:
#  Accuracy: 91.9%, Avg loss: 0.222340
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.287621
#
# Epoch 5
# -------------------------------
# Train Error:
#  Accuracy: 92.4%, Avg loss: 0.203620
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.287725
#
# Epoch 6
# -------------------------------
# Train Error:
#  Accuracy: 93.0%, Avg loss: 0.190550
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.292653
#
# Epoch 7
# -------------------------------
# Train Error:
#  Accuracy: 93.7%, Avg loss: 0.172673
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.298504
#
# Epoch 8
# -------------------------------
# Train Error:
#  Accuracy: 94.0%, Avg loss: 0.161758
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.312830
#
# Epoch 9
# -------------------------------
# Train Error:
#  Accuracy: 94.6%, Avg loss: 0.149705
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.324256
#
# Epoch 10
# -------------------------------
# Train Error:
#  Accuracy: 95.0%, Avg loss: 0.137993
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.383832
#
# Epoch 11
# -------------------------------
# Train Error:
#  Accuracy: 95.3%, Avg loss: 0.127802
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.370901
#
# Epoch 12
# -------------------------------
# Train Error:
#  Accuracy: 95.5%, Avg loss: 0.123222
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.376542
#
# Epoch 13
# -------------------------------
# Train Error:
#  Accuracy: 95.8%, Avg loss: 0.115980
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.424389
#
# Epoch 14
# -------------------------------
# Train Error:
#  Accuracy: 96.2%, Avg loss: 0.105157
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.273358
#
# Epoch 6
# -------------------------------
# Train Error:
#  Accuracy: 92.9%, Avg loss: 0.195329
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.302324
#
# Epoch 7
# -------------------------------
# Train Error:
#  Accuracy: 93.3%, Avg loss: 0.182306
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.277466
#
# Epoch 8
# -------------------------------
# Train Error:
#  Accuracy: 93.7%, Avg loss: 0.171241
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.298030
#
# Epoch 9
# -------------------------------
# Train Error:
#  Accuracy: 94.1%, Avg loss: 0.161520
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.317076
#
# Epoch 10
# -------------------------------
# Train Error:
#  Accuracy: 94.5%, Avg loss: 0.152170
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.307981
#
# Epoch 11
# -------------------------------
# Train Error:
#  Accuracy: 94.7%, Avg loss: 0.146265
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.342370
#
# Epoch 12
# -------------------------------
# Train Error:
#  Accuracy: 95.0%, Avg loss: 0.136286
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.319525
#
# Epoch 13
# -------------------------------
# Train Error:
#  Accuracy: 95.0%, Avg loss: 0.132138
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.357529
#
# Epoch 14
# -------------------------------
# Train Error:
#  Accuracy: 95.6%, Avg loss: 0.122607
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.356186
#
# Epoch 15
# -------------------------------
# Train Error:
#  Accuracy: 95.6%, Avg loss: 0.119278
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.377709
#
# Epoch 16
# -------------------------------
# Train Error:
#  Accuracy: 95.9%, Avg loss: 0.112392
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.375036
#
# Epoch 17
# -------------------------------
# Train Error:
#  Accuracy: 96.2%, Avg loss: 0.104015
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.378669
#
# Epoch 18
# -------------------------------
# Train Error:
#  Accuracy: 96.2%, Avg loss: 0.102529
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.408162
#
# Epoch 19
# -------------------------------
# Train Error:
#  Accuracy: 96.3%, Avg loss: 0.102009
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.414993
#
# Epoch 20
# -------------------------------
# Train Error:
#  Accuracy: 96.6%, Avg loss: 0.094872
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.425152
#
# Epoch 21
# -------------------------------
# Train Error:
#  Accuracy: 96.8%, Avg loss: 0.087681
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.460506
#
# Epoch 22
# -------------------------------
# Train Error:
#  Accuracy: 96.7%, Avg loss: 0.089604
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.495541
#
# Epoch 23
# -------------------------------
# Train Error:
#  Accuracy: 97.0%, Avg loss: 0.082180
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.529634
#
# Epoch 24
# -------------------------------
# Train Error:
#  Accuracy: 97.1%, Avg loss: 0.079949
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.520692
#
# Epoch 25
# -------------------------------
# Train Error:
#  Accuracy: 97.2%, Avg loss: 0.079552
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.484840
#
# Epoch 26
# -------------------------------
# Train Error:
#  Accuracy: 97.4%, Avg loss: 0.075480
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.539440
#
# Epoch 27
# -------------------------------
# Train Error:
#  Accuracy: 97.3%, Avg loss: 0.077386
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.569472
#
# Epoch 28
# -------------------------------
# Train Error:
#  Accuracy: 97.4%, Avg loss: 0.072230
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.594633
#
# Epoch 29
# -------------------------------
# Train Error:
#  Accuracy: 97.6%, Avg loss: 0.069151
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.559498
#
# Epoch 30
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.071167
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.636783
#
# Done!
# {2: [89.27000000000001, 0.6994404390833939], 3: [88.9, 0.7008858083919355], 4: [90.11, 0.7185066553280588], 5: [89.75999999999999, 0.6136977351300276], 6: [89.52, 0.6367825904184845]}

# %%
class MyDynamicModel2(nn.Module):
    def __init__(self, num_channels=8):
        super(MyDynamicModel2, self).__init__()
        self.num_channels = num_channels
        
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=self.num_channels//2, kernel_size=5, padding=2), #1x28x28 -> num_channelsx28x28
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2) #num_channelsx14x14
        )
        
        self.layer2 = nn.Sequential(
            nn.Conv2d(in_channels=self.num_channels//2, out_channels=self.num_channels, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(2, 2) #num_channelsx7x7
        )

        self.fcl = nn.Sequential(
            nn.Linear(in_features=self.num_channels * 7 * 7, out_features=1024),
            nn.Dropout(0.2),
            nn.Linear(in_features=1024, out_features=10)
        )
        
    def forward(self, x):
        x = self.layer1(x)
        x = self.layer2(x)
        x = x.view(x.size(0), -1)
        out = self.fcl(x)
        return out

# %%
for num_channels in range(3,8):
    print(f"No. of channels: {2**num_channels}")
    model = MyDynamicModel2(num_channels=2**num_channels)
    test_acc, test_loss = main("Adam")
    channels_dict[num_channels] = [(test_acc*100), test_loss] 
    print(channels_dict)
# Out:
# No. of channels: 8
# Training with: Adam...
# Epoch 1
# -------------------------------
# Train Error:
#  Accuracy: 84.8%, Avg loss: 0.421276
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.318389
#
# Epoch 2
# -------------------------------
# Train Error:
#  Accuracy: 89.6%, Avg loss: 0.289018
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.302600
#
# Epoch 3
# -------------------------------
# Train Error:
#  Accuracy: 91.1%, Avg loss: 0.249632
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.295702
#
# Epoch 4
# -------------------------------
# Train Error:
#  Accuracy: 91.8%, Avg loss: 0.228284
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.279947
#
# Epoch 5
# -------------------------------
# Train Error:
#  Accuracy: 92.6%, Avg loss: 0.204420
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.294140
#
# Epoch 6
# -------------------------------
# Train Error:
#  Accuracy: 93.0%, Avg loss: 0.193064
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.293937
#
# Epoch 7
# -------------------------------
# Train Error:
#  Accuracy: 93.5%, Avg loss: 0.175463
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.299323
#
# Epoch 8
# -------------------------------
# Train Error:
#  Accuracy: 93.8%, Avg loss: 0.167257
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.298490
#
# Epoch 9
# -------------------------------
# Train Error:
#  Accuracy: 94.2%, Avg loss: 0.155843
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.305431
#
# Epoch 10
# -------------------------------
# Train Error:
#  Accuracy: 94.8%, Avg loss: 0.143256
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.332473
#
# Epoch 11
# -------------------------------
# Train Error:
#  Accuracy: 94.9%, Avg loss: 0.136428
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.352391
#
# Epoch 12
# -------------------------------
# Train Error:
#  Accuracy: 95.3%, Avg loss: 0.127211
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.353301
#
# Epoch 13
# -------------------------------
# Train Error:
#  Accuracy: 95.7%, Avg loss: 0.117873
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.398181
#
# Epoch 14
# -------------------------------
# Train Error:
#  Accuracy: 95.9%, Avg loss: 0.112766
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.374041
#
# Epoch 15
# -------------------------------
# Train Error:
#  Accuracy: 96.2%, Avg loss: 0.104114
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.381237
#
# Epoch 16
# -------------------------------
# Train Error:
#  Accuracy: 96.4%, Avg loss: 0.099589
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.437047
#
# Epoch 17
# -------------------------------
# Train Error:
#  Accuracy: 96.3%, Avg loss: 0.098777
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.424228
#
# Epoch 18
# -------------------------------
# Train Error:
#  Accuracy: 96.6%, Avg loss: 0.092511
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.467905
#
# Epoch 19
# -------------------------------
# Train Error:
#  Accuracy: 96.9%, Avg loss: 0.088013
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.457863
#
# Epoch 20
# -------------------------------
# Train Error:
#  Accuracy: 97.0%, Avg loss: 0.082810
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.492724
#
# Epoch 21
# -------------------------------
# Train Error:
#  Accuracy: 97.0%, Avg loss: 0.081203
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.543569
#
# Epoch 22
# -------------------------------
# Train Error:
#  Accuracy: 96.8%, Avg loss: 0.086926
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.485327
#
# Epoch 23
# -------------------------------
# Train Error:
#  Accuracy: 97.4%, Avg loss: 0.074210
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.547835
#
# Epoch 24
# -------------------------------
# Train Error:
#  Accuracy: 97.4%, Avg loss: 0.076102
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.561068
#
# Epoch 25
# -------------------------------
# Train Error:
#  Accuracy: 97.3%, Avg loss: 0.076543
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.545806
#
# Epoch 26
# -------------------------------
# Train Error:
#  Accuracy: 97.6%, Avg loss: 0.068910
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.586947
#
# Epoch 27
# -------------------------------
# Train Error:
#  Accuracy: 97.7%, Avg loss: 0.066683
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.624986
#
# Epoch 28
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.071942
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.553846
#
# Epoch 29
# -------------------------------
# Train Error:
#  Accuracy: 97.7%, Avg loss: 0.064743
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.643516
#
# Epoch 30
# -------------------------------
# Train Error:
#  Accuracy: 97.8%, Avg loss: 0.065055
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.684288
#
# Done!
# {3: [89.13, 0.6842881385592898]}
# No. of channels: 16
# Training with: Adam...
# Epoch 1
# -------------------------------
# Train Error:
#  Accuracy: 85.1%, Avg loss: 0.416714
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.329933
#
# Epoch 2
# -------------------------------
# Train Error:
#  Accuracy: 89.8%, Avg loss: 0.285176
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.338760
#
# Epoch 14
# -------------------------------
# Train Error:
#  Accuracy: 95.0%, Avg loss: 0.135871
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.345515
#
# Epoch 15
# -------------------------------
# Train Error:
#  Accuracy: 95.1%, Avg loss: 0.131155
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.339892
#
# Epoch 16
# -------------------------------
# Train Error:
#  Accuracy: 95.3%, Avg loss: 0.123577
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.374535
#
# Epoch 17
# -------------------------------
# Train Error:
#  Accuracy: 95.5%, Avg loss: 0.121889
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.366870
#
# Epoch 18
# -------------------------------
# Train Error:
#  Accuracy: 95.7%, Avg loss: 0.115617
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.394608
#
# Epoch 19
# -------------------------------
# Train Error:
#  Accuracy: 95.8%, Avg loss: 0.112708
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.382102
#
# Epoch 20
# -------------------------------
# Train Error:
#  Accuracy: 96.1%, Avg loss: 0.107929
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.420108
#
# Epoch 21
# -------------------------------
# Train Error:
#  Accuracy: 96.1%, Avg loss: 0.104567
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.422010
#
# Epoch 22
# -------------------------------
# Train Error:
#  Accuracy: 96.4%, Avg loss: 0.099470
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.452219
#
# Epoch 23
# -------------------------------
# Train Error:
#  Accuracy: 96.5%, Avg loss: 0.095557
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.469272
#
# Epoch 24
# -------------------------------
# Train Error:
#  Accuracy: 96.6%, Avg loss: 0.093517
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.447385
#
# Epoch 25
# -------------------------------
# Train Error:
#  Accuracy: 96.7%, Avg loss: 0.090451
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.508241
#
# Epoch 26
# -------------------------------
# Train Error:
#  Accuracy: 96.9%, Avg loss: 0.088348
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.533469
#
# Epoch 27
# -------------------------------
# Train Error:
#  Accuracy: 96.8%, Avg loss: 0.087645
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.532142
#
# Epoch 28
# -------------------------------
# Train Error:
#  Accuracy: 97.1%, Avg loss: 0.082068
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.541410
#
# Epoch 29
# -------------------------------
# Train Error:
#  Accuracy: 97.1%, Avg loss: 0.080543
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.543388
#
# Epoch 30
# -------------------------------
# Train Error:
#  Accuracy: 97.1%, Avg loss: 0.084587
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.542053
#
# Done!
# {3: [89.13, 0.6842881385592898], 4: [89.71000000000001, 0.6729590664380438], 5: [89.63, 0.48160805359814957], 6: [89.66, 0.542052658144266]}
# No. of channels: 128
# Training with: Adam...
# Epoch 1
# -------------------------------
# Train Error:
#  Accuracy: 85.3%, Avg loss: 0.408146
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.321789
#
# Epoch 2
# -------------------------------
# Train Error:
#  Accuracy: 89.8%, Avg loss: 0.282620
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.322117
#
# Epoch 3
# -------------------------------
# Train Error:
#  Accuracy: 91.1%, Avg loss: 0.248211
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.297677
#
# Epoch 4
# -------------------------------
# Train Error:
#  Accuracy: 91.8%, Avg loss: 0.224612
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.276947
#
# Epoch 5
# -------------------------------
# Train Error:
#  Accuracy: 92.5%, Avg loss: 0.208016
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.292220
#
# Epoch 6
# -------------------------------
# Train Error:
#  Accuracy: 93.0%, Avg loss: 0.191036
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.296404
#
# Epoch 7
# -------------------------------
# Train Error:
#  Accuracy: 93.6%, Avg loss: 0.177103
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.306790
#
# Epoch 8
# -------------------------------
# Train Error:
#  Accuracy: 94.1%, Avg loss: 0.159836
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.315158
#
# Epoch 9
# -------------------------------
# Train Error:
#  Accuracy: 94.4%, Avg loss: 0.150984
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.298189
#
# Epoch 10
# -------------------------------
# Train Error:
#  Accuracy: 94.9%, Avg loss: 0.140206
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.320039
#
# Epoch 11
# -------------------------------
# Train Error:
#  Accuracy: 95.2%, Avg loss: 0.130587
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.359633
#
# Epoch 12
# -------------------------------
# Train Error:
#  Accuracy: 95.6%, Avg loss: 0.120550
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.357181
#
# Epoch 13
# -------------------------------
# Train Error:
#  Accuracy: 95.8%, Avg loss: 0.117914
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.364196
#
# Epoch 14
# -------------------------------
# Train Error:
#  Accuracy: 96.1%, Avg loss: 0.105572
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.407494
#
# Epoch 15
# -------------------------------
# Train Error:
#  Accuracy: 96.3%, Avg loss: 0.099146
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.442317
#
# Epoch 16
# -------------------------------
# Train Error:
#  Accuracy: 96.4%, Avg loss: 0.098872
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.433853
#
# Epoch 17
# -------------------------------
# Train Error:
#  Accuracy: 96.8%, Avg loss: 0.089226
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.434351
#
# Epoch 18
# -------------------------------
# Train Error:
#  Accuracy: 96.8%, Avg loss: 0.091056
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.451965
#
# Epoch 19
# -------------------------------
# Train Error:
#  Accuracy: 97.0%, Avg loss: 0.083329
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.467249
#
# Epoch 20
# -------------------------------
# Train Error:
#  Accuracy: 97.1%, Avg loss: 0.082966
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.494271
#
# Epoch 21
# -------------------------------
# Train Error:
#  Accuracy: 97.1%, Avg loss: 0.081498
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.500526
#
# Epoch 22
# -------------------------------
# Train Error:
#  Accuracy: 97.4%, Avg loss: 0.072419
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.521490
#
# Epoch 23
# -------------------------------
# Train Error:
#  Accuracy: 97.4%, Avg loss: 0.074521
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.540389
#
# Epoch 24
# -------------------------------
# Train Error:
#  Accuracy: 97.7%, Avg loss: 0.063750
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.542440
#
# Epoch 25
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.070329
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.559668
#
# Epoch 26
# -------------------------------
# Train Error:
#  Accuracy: 97.4%, Avg loss: 0.073623
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.557078
#
# Epoch 27
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.071480
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.657387
#
# Epoch 28
# -------------------------------
# Train Error:
#  Accuracy: 97.8%, Avg loss: 0.061713
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.630292
#
# Epoch 29
# -------------------------------
# Train Error:
#  Accuracy: 97.8%, Avg loss: 0.062316
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.689740
#
# Epoch 30
# -------------------------------
# Train Error:
#  Accuracy: 97.9%, Avg loss: 0.060810
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.653382
#
# Done!
# {3: [89.13, 0.6842881385592898], 4: [89.71000000000001, 0.6729590664380438], 5: [89.63, 0.48160805359814957], 6: [89.66, 0.542052658144266], 7: [90.01, 0.6533816583724514]}

# %%
class DeformCNN(nn.Module):

    def __init__(self):
        super(DeformCNN, self).__init__()

        self.layer = ops.DeformConv2d(in_channels=1, out_channels=64, kernel_size=3, stride=1, padding=1, dilation=1)
        kernel_height, kernel_width = self.layer.kernel_size
        offset_channels = 2 * kernel_height * kernel_width
        self.offsets = nn.Conv2d(1, offset_channels, kernel_size=3, padding=1)
        self.out_channels = 32

        self.layer2 = ops.DeformConv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1, dilation=1)
        kernel_height2, kernel_width2 = self.layer2.kernel_size
        offset_channels2 = 2 * kernel_height2 * kernel_width2
        self.offsets2 = nn.Conv2d(64, offset_channels2, kernel_size=3, padding=1)
        self.out_channels = 64

        self.fc1 = nn.Linear(in_features=64*28*28, out_features=600)
        self.drop = nn.Dropout2d(0.25)
        self.fc2 = nn.Linear(in_features=600, out_features=120)
        self.fc3 = nn.Linear(in_features=120, out_features=10)

    def forward(self, x):
        offset = self.offsets(x)
        # print('offset1: ', offset.shape)
        out = self.layer(x.float(), offset.float()).to(x)
        # print('out1: ', out.shape)
        # print(out.shape)
        offset2 = self.offsets2(out)
        # print('offset2: ', offset2.shape)
        out = self.layer2(out.float(), offset2.float()).to(out)
        # print('out2: ', out)

        out = out.view(out.size(0), -1)
        out = self.fc1(out)
        out = self.drop(out)
        out = self.fc2(out)
        out = self.fc3(out)

        return out

# %%
model = DeformCNN()
test_acc, test_loss = main("Adam")
deform_dict = [(test_acc*100), test_loss]
print(deform_dict)
# Out:
# Training with: Adam...
# Epoch 1
# -------------------------------
# Train Error:
#  Accuracy: 85.7%, Avg loss: 0.391619
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.314148
#
# Epoch 2
# -------------------------------
# Train Error:
#  Accuracy: 90.2%, Avg loss: 0.272941
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.277779
#
# Epoch 3
# -------------------------------
# Train Error:
#  Accuracy: 91.5%, Avg loss: 0.238613
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.282961
#
# Epoch 4
# -------------------------------
# Train Error:
#  Accuracy: 92.2%, Avg loss: 0.213255
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.289025
#
# Epoch 5
# -------------------------------
# Train Error:
#  Accuracy: 93.0%, Avg loss: 0.193641
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.290033
#
# Epoch 6
# -------------------------------
# Train Error:
#  Accuracy: 93.5%, Avg loss: 0.178123
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.287284
#
# Epoch 7
# -------------------------------
# Train Error:
#  Accuracy: 93.9%, Avg loss: 0.165359
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.296325
#
# Epoch 8
# -------------------------------
# Train Error:
#  Accuracy: 94.6%, Avg loss: 0.149297
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.295867
#
# Epoch 9
# -------------------------------
# Train Error:
#  Accuracy: 95.0%, Avg loss: 0.138561
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.335521
#
# Epoch 10
# -------------------------------
# Train Error:
#  Accuracy: 95.5%, Avg loss: 0.125771
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.360273
#
# Epoch 11
# -------------------------------
# Train Error:
#  Accuracy: 95.7%, Avg loss: 0.117224
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.363309
#
# Epoch 12
# -------------------------------
# Train Error:
#  Accuracy: 96.0%, Avg loss: 0.112058
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.348649
#
# Epoch 13
# -------------------------------
# Train Error:
#  Accuracy: 96.3%, Avg loss: 0.102298
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.383827
#
# Epoch 14
# -------------------------------
# Train Error:
#  Accuracy: 96.4%, Avg loss: 0.099421
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.373765
#
# Epoch 15
# -------------------------------
# Train Error:
#  Accuracy: 96.8%, Avg loss: 0.087929
# Test Error:
#  Accuracy: 90.4%, Avg loss: 0.431177
#
# Epoch 16
# -------------------------------
# Train Error:
#  Accuracy: 96.6%, Avg loss: 0.092276
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.432318
#
# Epoch 17
# -------------------------------
# Train Error:
#  Accuracy: 97.2%, Avg loss: 0.078598
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.454907
#
# Epoch 18
# -------------------------------
# Train Error:
#  Accuracy: 97.2%, Avg loss: 0.077760
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.568256
#
# Epoch 19
# -------------------------------
# Train Error:
#  Accuracy: 97.2%, Avg loss: 0.077486
# Test Error:
#  Accuracy: 89.9%, Avg loss: 0.519516
#
# Epoch 20
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.071076
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.527039
#
# Epoch 21
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.068550
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.528105
#
# Epoch 22
# -------------------------------
# Train Error:
#  Accuracy: 97.5%, Avg loss: 0.070249
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.576590
#
# Epoch 23
# -------------------------------
# Train Error:
#  Accuracy: 97.7%, Avg loss: 0.067195
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.650151
#
# Epoch 24
# -------------------------------
# Train Error:
#  Accuracy: 97.8%, Avg loss: 0.062781
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.598689
#
# Epoch 25
# -------------------------------
# Train Error:
#  Accuracy: 97.8%, Avg loss: 0.063971
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.631370
#
# Epoch 26
# -------------------------------
# Train Error:
#  Accuracy: 98.0%, Avg loss: 0.059829
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.618506
#
# Epoch 27
# -------------------------------
# Train Error:
#  Accuracy: 97.9%, Avg loss: 0.063182
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.612495
#
# Epoch 28
# -------------------------------
# Train Error:
#  Accuracy: 98.1%, Avg loss: 0.056833
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.657127
#
# Epoch 29
# -------------------------------
# Train Error:
#  Accuracy: 98.2%, Avg loss: 0.054271
# Test Error:
#  Accuracy: 89.8%, Avg loss: 0.673703
#
# Epoch 30
# -------------------------------
# Train Error:
#  Accuracy: 98.2%, Avg loss: 0.052952
# Test Error:
#  Accuracy: 89.6%, Avg loss: 0.784643
#
# Done!
# [89.64, 0.784643347333571]

# %%
[89.53999999999999, 0.633607772801807]
